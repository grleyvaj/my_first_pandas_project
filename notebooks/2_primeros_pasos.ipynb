# %%
import pandas as pd

# %%
naranjas = pd.Series([4,9,2,6,10,200])

# %%
print(naranjas)
# Out:
# 0      4
# 1      9
# 2      2
# 3      6
# 4     10
# 5    200
# dtype: int64

# %%
manzanas = pd.Series([60,22,1,79,2,8])

# %%
print(manzanas)
# Out:
# 0    60
# 1    22
# 2     1
# 3    79
# 4     2
# 5     8
# dtype: int64
