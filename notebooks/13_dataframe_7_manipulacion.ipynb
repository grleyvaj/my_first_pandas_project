# %%
import pandas as pd

# %%
df = pd.read_csv("estudiantes.csv")

# %%
df
# Out:
#     NOMBRE  EDAD GENERO       CARRERA SEMESTRE
# 0   Victor    28      M     Auditoria  Primero
# 1   Josefa    23      F   Informatica  Primero
# 2     Raul    26      M       Derecho   Quinto
# 3  Mariana    27      F   Informatica  Septimo
# 4  Rodrigo    22      M       Derecho  Tercero
# 5  Gustavo    25      M  Arquitectura  Septimo
# 6     Lucy    23      F   Informatica  Primero
# 7    Sofia    24      F      Economia   Noveno

# %%
df.iloc[1,3]
# Out:
# 'Informatica'

# %%
df.iloc[2,:3]
# Out:
# NOMBRE    Raul
# EDAD        26
# GENERO       M
# Name: 2, dtype: object

# %%
df.iloc[:2,3]
# Out:
# 0      Auditoria
# 1    Informatica
# Name: CARRERA, dtype: object

# %%
df.iloc[:2,:3]
# Out:
#    NOMBRE  EDAD GENERO
# 0  Victor    28      M
# 1  Josefa    23      F

# %%
df.loc[:3,("NOMBRE", "CARRERA")]
# Out:
#     NOMBRE      CARRERA
# 0   Victor    Auditoria
# 1   Josefa  Informatica
# 2     Raul      Derecho
# 3  Mariana  Informatica

# %%
# añadir columnas al dataframe
df["TURNO"] = pd.Series(["tarde", "noche","tarde", "noche","tarde", "noche"])

# %%
df  # cuando se crea con columna, asig NaN para si no se añaden elementos para todas las filas q ya se tienen
# Out:
#     NOMBRE  EDAD GENERO       CARRERA SEMESTRE  TURNO
# 0   Victor    28      M     Auditoria  Primero  tarde
# 1   Josefa    23      F   Informatica  Primero  noche
# 2     Raul    26      M       Derecho   Quinto  tarde
# 3  Mariana    27      F   Informatica  Septimo  noche
# 4  Rodrigo    22      M       Derecho  Tercero  tarde
# 5  Gustavo    25      M  Arquitectura  Septimo  noche
# 6     Lucy    23      F   Informatica  Primero    NaN
# 7    Sofia    24      F      Economia   Noveno    NaN

# %%
df["NUEVO"] = ["tarde", "noche","tarde", "noche","tarde", "noche","tarde", "noche"] 
# si se tienen 8 filas, hay q añadirle valores a dicha columna para las 8 filas q ya se tienen, sino da error,
# en eso difiere de crearla como Serie, porq la Serie completa con NaN

# %%
# eliminar columna
SEMESTRE = df.pop("SEMESTRE")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /media/Datos/FINERIO/py-workspace/notebooks/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SEMESTRE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 2
#       1 # eliminar columna
# ...

# %%
df
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO  NUEVO
# 0   Victor    28      M     Auditoria  tarde  tarde
# 1   Josefa    23      F   Informatica  noche  noche
# 2     Raul    26      M       Derecho  tarde  tarde
# 3  Mariana    27      F   Informatica  noche  noche
# 4  Rodrigo    22      M       Derecho  tarde  tarde
# 5  Gustavo    25      M  Arquitectura  noche  noche
# 6     Lucy    23      F   Informatica    NaN  tarde
# 7    Sofia    24      F      Economia    NaN  noche

# %%
df.drop([1,2])
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO  NUEVO
# 0   Victor    28      M     Auditoria  tarde  tarde
# 3  Mariana    27      F   Informatica  noche  noche
# 4  Rodrigo    22      M       Derecho  tarde  tarde
# 5  Gustavo    25      M  Arquitectura  noche  noche
# 6     Lucy    23      F   Informatica    NaN  tarde
# 7    Sofia    24      F      Economia    NaN  noche

# %%
df.iloc[1] = ["Carlos", 28, "H", "Info", "tarde", "tarde"]

# %%
df
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO  NUEVO
# 0   Victor    28      M     Auditoria  tarde  tarde
# 1   Carlos    28      H          Info  tarde  tarde
# 2     Raul    26      M       Derecho  tarde  tarde
# 3  Mariana    27      F   Informatica  noche  noche
# 4  Rodrigo    22      M       Derecho  tarde  tarde
# 5  Gustavo    25      M  Arquitectura  noche  noche
# 6     Lucy    23      F   Informatica    NaN  tarde
# 7    Sofia    24      F      Economia    NaN  noche

# %%
df.max
# Out:
# <bound method DataFrame.max of     NOMBRE  EDAD GENERO       CARRERA  TURNO  NUEVO
# 0   Victor    28      M     Auditoria  tarde  tarde
# 1   Carlos    28      H          Info  tarde  tarde
# 2     Raul    26      M       Derecho  tarde  tarde
# 3  Mariana    27      F   Informatica  noche  noche
# 4  Rodrigo    22      M       Derecho  tarde  tarde
# 5  Gustavo    25      M  Arquitectura  noche  noche
# 6     Lucy    23      F   Informatica    NaN  tarde
# 7    Sofia    24      F      Economia    NaN  noche>

# %%
print(df.shape[0])
# Out:
# 8

# %%
df.reset_index(drop=True)
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO  NUEVO
# 0   Victor    28      M     Auditoria  tarde  tarde
# 1   Carlos    28      H          Info  tarde  tarde
# 2     Raul    26      M       Derecho  tarde  tarde
# 3  Mariana    27      F   Informatica  noche  noche
# 4  Rodrigo    22      M       Derecho  tarde  tarde
# 5  Gustavo    25      M  Arquitectura  noche  noche
# 6     Lucy    23      F   Informatica    NaN  tarde
# 7    Sofia    24      F      Economia    NaN  noche

# %%
df.iloc[8] = ["Carlos", 28, "H", "Info", "tarde", "tarde"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 df.iloc[8] = ["Carlos", 28, "H", "Info", "tarde", "tarde"]
#
# File /media/Datos/FINERIO/py-workspace/notebooks/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:882, in _LocationIndexer.__setitem__(self, key, value)
#     880     key = com.apply_if_callable(key, self.obj)
#     881 indexer = self._get_setitem_indexer(key)
# --> 882 self._has_valid_setitem_indexer(key)
#     884 iloc = self if self.name == "iloc" else self.obj.iloc
#     885 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /media/Datos/FINERIO/py-workspace/notebooks/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1608, in _iLocIndexer._has_valid_setitem_indexer(self, indexer)
#    1606 elif is_integer(i):
#    1607     if i >= len(ax):
# ...

# %%
df
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO  NUEVO
# 0   Victor    28      M     Auditoria  tarde  tarde
# 1   Carlos    28      H          Info  tarde  tarde
# 2     Raul    26      M       Derecho  tarde  tarde
# 3  Mariana    27      F   Informatica  noche  noche
# 4  Rodrigo    22      M       Derecho  tarde  tarde
# 5  Gustavo    25      M  Arquitectura  noche  noche
# 6     Lucy    23      F   Informatica    NaN  tarde
# 7   Carlos    28      H          Info  tarde  tarde

# %%
df[(df["GENERO"]=="F") & (df["EDAD"] >= 23)]
# Out:
#     NOMBRE  EDAD GENERO      CARRERA  TURNO  NUEVO
# 3  Mariana    27      F  Informatica  noche  noche
# 6     Lucy    23      F  Informatica    NaN  tarde

# %%
df.sort_values("CARRERA")
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO  NUEVO
# 5  Gustavo    25      M  Arquitectura  noche  noche
# 0   Victor    28      M     Auditoria  tarde  tarde
# 2     Raul    26      M       Derecho  tarde  tarde
# 4  Rodrigo    22      M       Derecho  tarde  tarde
# 1   Carlos    28      H          Info  tarde  tarde
# 7   Carlos    28      H          Info  tarde  tarde
# 3  Mariana    27      F   Informatica  noche  noche
# 6     Lucy    23      F   Informatica    NaN  tarde

# %%
df.sort_values("EDAD")
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO  NUEVO
# 4  Rodrigo    22      M       Derecho  tarde  tarde
# 6     Lucy    23      F   Informatica    NaN  tarde
# 5  Gustavo    25      M  Arquitectura  noche  noche
# 2     Raul    26      M       Derecho  tarde  tarde
# 3  Mariana    27      F   Informatica  noche  noche
# 1   Carlos    28      H          Info  tarde  tarde
# 0   Victor    28      M     Auditoria  tarde  tarde
# 7   Carlos    28      H          Info  tarde  tarde

# %%
df.dropna() # eliminar datos desconocidos
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO  NUEVO
# 0   Victor    28      M     Auditoria  tarde  tarde
# 1   Carlos    28      H          Info  tarde  tarde
# 2     Raul    26      M       Derecho  tarde  tarde
# 3  Mariana    27      F   Informatica  noche  noche
# 4  Rodrigo    22      M       Derecho  tarde  tarde
# 5  Gustavo    25      M  Arquitectura  noche  noche
# 7   Carlos    28      H          Info  tarde  tarde
